# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Mall_Customers.csv")
df
# Out:
#      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0             1    Male   19                  15              39
# 1             2    Male   21                  15              81
# 2             3  Female   20                  16               6
# 3             4  Female   23                  16              77
# 4             5  Female   31                  17              40
# ..          ...     ...  ...                 ...             ...
# 195         196  Female   35                 120              79
# 196         197  Female   45                 126              28
# 197         198    Male   32                 126              74
# 198         199    Male   32                 137              18
# 199         200    Male   30                 137              83
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   CustomerID          200 non-null    int64
#  1   Genre               200 non-null    object
#  2   Age                 200 non-null    int64
#  3   Annual_Income_(k$)  200 non-null    int64
#  4   Spending_Score      200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      CustomerID   Genre  Age  Annual_Income_(k$)  Spending_Score
# 0             1    Male   19                  15              39
# 1             2    Male   21                  15              81
# 2             3  Female   20                  16               6
# 3             4  Female   23                  16              77
# 4             5  Female   31                  17              40
# ..          ...     ...  ...                 ...             ...
# 195         196  Female   35                 120              79
# 196         197  Female   45                 126              28
# 197         198    Male   32                 126              74
# 198         199    Male   32                 137              18
# 199         200    Male   30                 137              83
#
# [200 rows x 5 columns]>

# %%
plt.scatter(df['Annual_Income_(k$)'], df['Spending_Score'])
plt.xlabel('Annual Income (k$)')
plt.ylabel('Spending Score')
plt.title('Annual Income vs Spending Score')
plt.show()

# %%
plt.hist(df['Age'], bins=10)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
gender_counts = df['Genre'].value_counts()
plt.bar(gender_counts.index, gender_counts.values)
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')
plt.show()

# %%
plt.boxplot(df['Spending_Score'])
plt.ylabel('Spending Score')
plt.title('Spending Score Distribution')
plt.show()

# %%
plt.plot(df['CustomerID'], df['Spending_Score'])
plt.xlabel('CustomerID')
plt.ylabel('Spending Score')
plt.title('Spending Score by CustomerID')
plt.show()

# %%
genre_counts = df['Genre'].value_counts()
plt.pie(genre_counts, labels=genre_counts.index, autopct='%1.1f%%')
plt.title('Gender Distribution')
plt.show()

# %%
plt.violinplot(df['Age'], vert=False)
plt.xlabel('Age')
plt.title('Age Distribution')
plt.show()

# %%
pd.plotting.scatter_matrix(df[['Age', 'Annual_Income_(k$)', 'Spending_Score']], figsize=(8, 8))
plt.suptitle('Scatter Matrix Plot')
plt.show()

# %%
income_groups = df.groupby(pd.cut(df['Annual_Income_(k$)'], bins=[0, 30, 60, 90, 120, 150])).size()
plt.barh(income_groups.index.astype(str), income_groups.values)
plt.xlabel('Count')
plt.ylabel('Annual Income (k$)')
plt.title('Annual Income Groups')
plt.show()

# %%
age_groups = df.groupby(pd.cut(df['Age'], bins=[0, 20, 30, 40, 50, 60, 70, 80])).size()
plt.stackplot(age_groups.index.astype(str), age_groups.values, labels=age_groups.index.astype(str), alpha=0.7)
plt.xlabel('Age Groups')
plt.ylabel('Count')
plt.title('Age Distribution')
plt.legend()
plt.show()

# %%
df.columns
# Out:
# Index(['CustomerID', 'Genre', 'Age', 'Annual_Income_(k$)', 'Spending_Score'], dtype='object')

# %%
import seaborn as sns

sns.boxplot(x='Genre', y='Spending_Score', data=df)
plt.xlabel('Gender')
plt.ylabel('Spending Score')
plt.title('Box Plot: Spending Score by Gender')
plt.show()
