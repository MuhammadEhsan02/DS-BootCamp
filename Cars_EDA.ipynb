# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
df = pd.read_csv('cars.csv',encoding = 'latin1')
df
# Out:
#               Brand Condition    Fuel  KMs Driven        Model    Price  \
# 0            Toyota      Used  Diesel         1.0        Prado  2100000
# 1            Suzuki      Used  Petrol    100000.0        Bolan   380000
# 2            Suzuki      Used     CNG     12345.0        Bolan   340000
# 3            Suzuki      Used  Petrol     94000.0         Alto   535000
# 4            Toyota      Used  Petrol    100000.0  Corolla XLI  1430000
# ...             ...       ...     ...         ...          ...      ...
# 24968        Toyota      Used     CNG    200000.0   Corolla XE  1070000
# 24969      Daihatsu       New  Petrol     10000.0        Cuore   390000
# 24970  Other Brands      Used     CNG    158715.0        Other   180000
# 24971        Suzuki      Used  Petrol         1.0         Alto   470000
# 24972        Toyota      Used  Petrol     48500.0  Corolla GLI  2050000
#
#       Registered City Transaction Type    Year
# 0             Karachi             Cash  1997.0
# ...

# %%
df.head()
# Out:
#     Brand Condition    Fuel  KMs Driven        Model    Price Registered City  \
# 0  Toyota      Used  Diesel         1.0        Prado  2100000         Karachi
# 1  Suzuki      Used  Petrol    100000.0        Bolan   380000         Karachi
# 2  Suzuki      Used     CNG     12345.0        Bolan   340000         Karachi
# 3  Suzuki      Used  Petrol     94000.0         Alto   535000         Karachi
# 4  Toyota      Used  Petrol    100000.0  Corolla XLI  1430000         Karachi
#
#   Transaction Type    Year
# 0             Cash  1997.0
# 1             Cash  2006.0
# 2             Cash  1998.0
# 3             Cash  2010.0
# 4             Cash  2013.0

# %%
df.tail()
# Out:
#               Brand Condition    Fuel  KMs Driven        Model    Price  \
# 24968        Toyota      Used     CNG    200000.0   Corolla XE  1070000
# 24969      Daihatsu       New  Petrol     10000.0        Cuore   390000
# 24970  Other Brands      Used     CNG    158715.0        Other   180000
# 24971        Suzuki      Used  Petrol         1.0         Alto   470000
# 24972        Toyota      Used  Petrol     48500.0  Corolla GLI  2050000
#
#       Registered City Transaction Type    Year
# 24968          Lahore             Cash  2001.0
# 24969         Karachi             Cash  2004.0
# 24970             NaN             Cash  2000.0
# 24971      Rawalpindi             Cash  2003.0
# 24972          Lahore             Cash  2017.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24973 entries, 0 to 24972
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             22836 non-null  object
#  1   Condition         22837 non-null  object
#  2   Fuel              22528 non-null  object
#  3   KMs Driven        22687 non-null  float64
#  4   Model             22525 non-null  object
#  5   Price             24973 non-null  int64
#  6   Registered City   20337 non-null  object
#  7   Transaction Type  22528 non-null  object
#  8   Year              22689 non-null  float64
# dtypes: float64(2), int64(1), object(6)
# memory usage: 1.7+ MB

# %%
df.columns
# Out:
# Index(['Brand', 'Condition', 'Fuel', 'KMs Driven', 'Model', 'Price',
#        'Registered City', 'Transaction Type', 'Year'],
#       dtype='object')

# %%
df.describe()
# Out:
#          KMs Driven         Price          Year
# count  2.268700e+04  2.497300e+04  22689.000000
# mean   1.278112e+05  9.128953e+05   2005.901626
# std    5.996726e+05  1.537134e+06      9.563804
# min    1.000000e+00  5.000000e+04   1915.000000
# 25%    1.600000e+04  3.800000e+05   2002.000000
# 50%    6.651000e+04  6.500000e+05   2008.000000
# 75%    1.000000e+05  1.145000e+06   2013.000000
# max    1.000000e+07  8.765432e+07   2020.000000

# %%
df.isnull().sum()
df = df.dropna()
df.isnull().sum()
df
# Out:
#           Brand Condition    Fuel  KMs Driven        Model    Price  \
# 0        Toyota      Used  Diesel         1.0        Prado  2100000
# 1        Suzuki      Used  Petrol    100000.0        Bolan   380000
# 2        Suzuki      Used     CNG     12345.0        Bolan   340000
# 3        Suzuki      Used  Petrol     94000.0         Alto   535000
# 4        Toyota      Used  Petrol    100000.0  Corolla XLI  1430000
# ...         ...       ...     ...         ...          ...      ...
# 24966    Toyota      Used  Petrol     76190.0       Avanza  1175000
# 24968    Toyota      Used     CNG    200000.0   Corolla XE  1070000
# 24969  Daihatsu       New  Petrol     10000.0        Cuore   390000
# 24971    Suzuki      Used  Petrol         1.0         Alto   470000
# 24972    Toyota      Used  Petrol     48500.0  Corolla GLI  2050000
#
#       Registered City Transaction Type    Year
# 0             Karachi             Cash  1997.0
# 1             Karachi             Cash  2006.0
# ...

# %%
df[df['Condition'] =='used']
df
# Out:
#           Brand Condition    Fuel  KMs Driven        Model    Price  \
# 0        Toyota      Used  Diesel         1.0        Prado  2100000
# 1        Suzuki      Used  Petrol    100000.0        Bolan   380000
# 2        Suzuki      Used     CNG     12345.0        Bolan   340000
# 3        Suzuki      Used  Petrol     94000.0         Alto   535000
# 4        Toyota      Used  Petrol    100000.0  Corolla XLI  1430000
# ...         ...       ...     ...         ...          ...      ...
# 24966    Toyota      Used  Petrol     76190.0       Avanza  1175000
# 24968    Toyota      Used     CNG    200000.0   Corolla XE  1070000
# 24969  Daihatsu       New  Petrol     10000.0        Cuore   390000
# 24971    Suzuki      Used  Petrol         1.0         Alto   470000
# 24972    Toyota      Used  Petrol     48500.0  Corolla GLI  2050000
#
#       Registered City Transaction Type    Year
# 0             Karachi             Cash  1997.0
# 1             Karachi             Cash  2006.0
# ...

# %%
df = df.drop(['Brand', 'Condition', 'Fuel', 'Model','Registered City', 'Transaction Type', 'Year'], axis=1)

# %%
df
# Out:
#        KMs Driven    Price
# 0             1.0  2100000
# 1        100000.0   380000
# 2         12345.0   340000
# 3         94000.0   535000
# 4        100000.0  1430000
# ...           ...      ...
# 24966     76190.0  1175000
# 24968    200000.0  1070000
# 24969     10000.0   390000
# 24971         1.0   470000
# 24972     48500.0  2050000
#
# [20334 rows x 2 columns]

# %%
p_val = df['Price'].values
p_val
# Out:
# array([2100000,  380000,  340000, ...,  180000,  470000, 2050000])

# %%
print("Mean:",np.mean(p_val))
print("Median:",np.median(p_val))
# Out:
# Mean: 912895.282264846
# Median: 650000.0

# %%
km_val = df['KMs Driven'].values
km_val
# Out:
# array([1.00000e+00, 1.00000e+05, 1.23450e+04, ..., 1.58715e+05,
#        1.00000e+00, 4.85000e+04])

# %%
print("Mean:",np.mean(km_val))
print("Median:",np.median(km_val))

trimmed_mean = stats.trim_mean(km_val, proportiontocut=0.1)
print("Trimmed Mean:",trimmed_mean)

weighted_mean = np.average(km_val, weights=p_val)
print("Weighted Mean:", weighted_mean)

sorted_data = np.sort(p_val)
cumulative_weights = np.cumsum(p_val)
threshold = np.sum(weights) / 2

weighted_median = sorted_data[np.argmax(cumulative_weights >= threshold)]
print("Weighted Median:", weighted_median)
# Out:
# Mean: nan
# Median: nan
# Trimmed Mean: 93490.0961509585
# Weighted Mean: nan
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-db2f9a90a8ae> in <cell line: 12>()
#      10 sorted_data = np.sort(p_val)
#      11 cumulative_weights = np.cumsum(p_val)
# ---> 12 threshold = np.sum(weights) / 2
#      13
#      14 weighted_median = sorted_data[np.argmax(cumulative_weights >= threshold)]
#
# NameError: name 'weights' is not defined

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

ax.boxplot(df['Price'])

plt.show()

# %%
# KMs Driven

fig, ax = plt.subplots()
ax.boxplot(df['KMs Driven'])

plt.show()

# %%
df.head()
# Out:
#     Brand Condition    Fuel  KMs Driven        Model    Price Registered City  \
# 0  Toyota      Used  Diesel         1.0        Prado  2100000         Karachi
# 1  Suzuki      Used  Petrol    100000.0        Bolan   380000         Karachi
# 2  Suzuki      Used     CNG     12345.0        Bolan   340000         Karachi
# 3  Suzuki      Used  Petrol     94000.0         Alto   535000         Karachi
# 4  Toyota      Used  Petrol    100000.0  Corolla XLI  1430000         Karachi
#
#   Transaction Type    Year
# 0             Cash  1997.0
# 1             Cash  2006.0
# 2             Cash  1998.0
# 3             Cash  2010.0
# 4             Cash  2013.0

# %%
# Day_05

# %%
df.columns
# Out:
# Index(['Brand', 'Condition', 'Fuel', 'KMs Driven', 'Model', 'Price',
#        'Registered City', 'Transaction Type', 'Year'],
#       dtype='object')

# %%
df.Brand
# Out:
# 0              Toyota
# 1              Suzuki
# 2              Suzuki
# 3              Suzuki
# 4              Toyota
#              ...
# 24968          Toyota
# 24969        Daihatsu
# 24970    Other Brands
# 24971          Suzuki
# 24972          Toyota
# Name: Brand, Length: 24973, dtype: object

# %%
df
# Out:
#               Brand Condition    Fuel  KMs Driven        Model    Price  \
# 0            Toyota      Used  Diesel         1.0        Prado  2100000
# 1            Suzuki      Used  Petrol    100000.0        Bolan   380000
# 2            Suzuki      Used     CNG     12345.0        Bolan   340000
# 3            Suzuki      Used  Petrol     94000.0         Alto   535000
# 4            Toyota      Used  Petrol    100000.0  Corolla XLI  1430000
# ...             ...       ...     ...         ...          ...      ...
# 24968        Toyota      Used     CNG    200000.0   Corolla XE  1070000
# 24969      Daihatsu       New  Petrol     10000.0        Cuore   390000
# 24970  Other Brands      Used     CNG    158715.0        Other   180000
# 24971        Suzuki      Used  Petrol         1.0         Alto   470000
# 24972        Toyota      Used  Petrol     48500.0  Corolla GLI  2050000
#
#       Registered City Transaction Type    Year
# 0             Karachi             Cash  1997.0
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Condition', 'Fuel', 'KMs Driven', 'Model', 'Price',
#        'Registered City', 'Transaction Type', 'Year'],
#       dtype='object')

# %%
ax = df.boxplot(by='Model', column='Model',figsize= (10,6))
ax.set_xlabel('')
ax.set_ylabel('Daily % of Delayed Flights')
plt.suptitle('')
#Alaska stands out as having the fewest delays, while American has the most delays:
# the lower quartile for American is higher than the upper quartile for Alaska.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-363c1c95270c> in <cell line: 1>()
# ----> 1 ax = df.boxplot(by='Model', column='Model',figsize= (10,6))
#       2 ax.set_xlabel('')
#       3 ax.set_ylabel('Daily % of Delayed Flights')
#       4 plt.suptitle('')
#       5 #Alaska stands out as having the fewest delays, while American has the most delays:
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     514 ):
#     515     plot_backend = _get_plot_backend(backend)
# --> 516     return plot_backend.boxplot_frame(
#     517         self,
#     518         column=column,
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
ax = sns.violinplot(data=df, x='Registered City', y='Brand')

ax.set_xlabel('')
# ax.set_ylabel('Daily % of Delayed Flights')
# plt.title('Violin Plot - Percentage of Carrier Delay by Airline')

plt.show()

#shows how many values lie in that area
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-924809179b7c> in <cell line: 5>()
#       3
#       4 plt.figure(figsize=(10, 6))
# ----> 5 ax = sns.violinplot(data=df, x='Registered City', y='Brand')
#       6
#       7 ax.set_xlabel('')
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in violinplot(data, x, y, hue, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2303 ):
#    2304
# -> 2305     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
#    2306                              bw, cut, scale, scale_hue, gridsize,
#    2307                              width, inner, split, dodge, orient, linewidth,
#
# ...

# %%
df.columns
# Out:
# Index(['Brand', 'Condition', 'Fuel', 'KMs Driven', 'Model', 'Price',
#        'Registered City', 'Transaction Type', 'Year'],
#       dtype='object')

# %%
df = pd.read_csv('cars.csv',encoding = 'latin1')
df
# Out:
#               Brand Condition    Fuel  KMs Driven        Model    Price  \
# 0            Toyota      Used  Diesel         1.0        Prado  2100000
# 1            Suzuki      Used  Petrol    100000.0        Bolan   380000
# 2            Suzuki      Used     CNG     12345.0        Bolan   340000
# 3            Suzuki      Used  Petrol     94000.0         Alto   535000
# 4            Toyota      Used  Petrol    100000.0  Corolla XLI  1430000
# ...             ...       ...     ...         ...          ...      ...
# 24968        Toyota      Used     CNG    200000.0   Corolla XE  1070000
# 24969      Daihatsu       New  Petrol     10000.0        Cuore   390000
# 24970  Other Brands      Used     CNG    158715.0        Other   180000
# 24971        Suzuki      Used  Petrol         1.0         Alto   470000
# 24972        Toyota      Used  Petrol     48500.0  Corolla GLI  2050000
#
#       Registered City Transaction Type    Year
# 0             Karachi             Cash  1997.0
# ...

# %%
df.Registered City
# Out:
#   File "<ipython-input-65-98ce96cf3cf5>", line 1
#     df.Registered City
#                   ^
# SyntaxError: invalid syntax

# %%
df.Price
# Out:
# 0        2100000
# 1         380000
# 2         340000
# 3         535000
# 4        1430000
#           ...
# 24968    1070000
# 24969     390000
# 24970     180000
# 24971     470000
# 24972    2050000
# Name: Price, Length: 24973, dtype: int64

# %%
ax = df.boxplot(by='Registered City', column='Price',figsize= (18,6))
ax.set_xlabel('')
# ax.set_ylabel('Daily % of Delayed Flights')
plt.suptitle('')
#Alaska stands out as having the fewest delays, while American has the most delays:
# the lower quartile for American is higher than the upper quartile for Alaska.
# Out:
# Text(0.5, 0.98, '')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(19, 6))
ax = sns.violinplot(data=df, x='Registered City', y='Price')

ax.set_xlabel('')
ax.set_ylabel('')
plt.title('')

plt.show()

#shows how many values lie in that area

# %%
df.Brand
# Out:
# 0              Toyota
# 1              Suzuki
# 2              Suzuki
# 3              Suzuki
# 4              Toyota
#              ...
# 24968          Toyota
# 24969        Daihatsu
# 24970    Other Brands
# 24971          Suzuki
# 24972          Toyota
# Name: Brand, Length: 24973, dtype: object
